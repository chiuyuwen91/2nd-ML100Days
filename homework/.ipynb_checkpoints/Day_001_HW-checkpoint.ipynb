# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

def mean_squared_error(y, yp):
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 267.086
# The Mean absolute error is 13.095

# %%
Assignment one
1.	協助學生在申請心中理想的研究所時，有一個評估的依據。
2.	這個資料夾是由Mohan S Acharya.所建立的，是受到UCLA的畢業資料夾所啟發而建立的，根據學生申請的資料，包含GRE.TOFEL.GPA等資料去評估學生是否會受到學校的青睞，給予入學資格。
3.	結構性資料以表格形式呈現，包括： 1. GRE Scores ( out of 340 ) 2. TOEFL Scores ( out of 120 ) 3. University Rating ( out of 5 ) 4. Statement of Purpose and Letter of Recommendation Strength ( out of 5 ) 5. Undergraduate GPA ( out of 10 ) 6. Research Experience ( either 0 or 1 ) 7. Chance of Admit ( ranging from 0 to 1 )
4.	學生可以申請上理想研究所的機率，MSE
Assignment two
1.	我對提升業績的定義是金錢上的實質報酬增加。而我的假設是，如果要提升業績有幾個因素可能會造成影響：載客率、載客時間（路徑）、服務品質、載客時段、載客地點、天氣、客源（app叫車、路邊招車、回頭客）、結帳方式等，所以需要搜集資料去找出最後收入和這些因素的關聯性，以便了解哪些因素會帶來較高的金錢報酬。
2.	在車隊中的每輛車上安裝app叫車系統，記錄下每位乘客的消費過程，路邊招車的則開手寫收據以複寫方式記錄下消費過程。
3.	資料將以表格的形式屬於資料性結構。
4.	把資料分兩筆，第一筆用相關係數的方式找出與實質報酬增加最相關的幾個因素，第二筆在去驗證是否這幾個因素真的帶來較高的金錢報酬。
# Out:
#   File "<ipython-input-8-9f1012d8ffab>", line 1
#     Assignment one
#                  ^
# SyntaxError: invalid syntax
